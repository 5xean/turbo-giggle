# %% [markdown]
# <a href="https://colab.research.google.com/github/5xean/turbo-giggle/blob/main/Colaboratory%EC%97%90_%EC%98%A4%EC%8B%A0_%EA%B2%83%EC%9D%84_%ED%99%98%EC%98%81%ED%95%A9%EB%8B%88%EB%8B%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import folium

# 리스본 중심 좌표 설정
lisbon_map = folium.Map(location=[38.7169, -9.1399], zoom_start=12)

# 명소 리스트 (한글이름, 원어이름, 위도, 경도, 지구)
places = [
    ("벨렘 탑 (Torre de Belém)", 38.6916, -9.2150, "벨렝"),
    ("제로니무스 수도원 (Mosteiro dos Jerónimos)", 38.6981, -9.2065, "벨렝"),
    ("상 조르제 성 (Castelo de São Jorge)", 38.7139, -9.1335, "알파마"),
    ("리스본 오세아나리움 (Oceanário de Lisboa)", 38.7630, -9.0951, "기타"),
    ("코메르시우 광장 (Praça do Comércio)", 38.7077, -9.1365, "바이샤"),
    ("페나 궁전 (Palácio da Pena)", 38.7875, -9.3907, "벨렝"),
    ("국립 아줄레주 박물관 (Museu Nacional do Azulejo)", 38.7344, -9.1151, "알파마"),
    ("헤갈레이라 별장 (Quinta da Regaleira)", 38.7955, -9.3977, "서부"),
    ("산타 주스타 엘리베이터 (Elevador de Santa Justa)", 38.7121, -9.1383, "바이샤"),
    ("발견 기념비 (Padrão dos Descobrimentos)", 38.6959, -9.2052, "벨렝"),
    ("신트라 (Sintra)", 38.8029, -9.3817, "서부"),
    ("카스카이스 (Cascais)", 38.6979, -9.4215, "서부"),
    ("호카곶 (Cabo da Roca)", 38.7804, -9.4989, "서부"),
    ("타임 아웃 마켓 (Time Out Market)", 38.7072, -9.1485, "기타"),
    ("국립마차박물관 (Museu Nacional dos Coches)", 38.6973, -9.2005, "벨렝"),
    ("아주다 국립 궁전 (Ajuda National Palace)", 38.7099, -9.2006, "벨렝"),
    ("국립고대박물관 (Museu Nacional de Arte Antiga)", 38.6988, -9.1981, "바이후알투"),
    ("4월 25일 다리 (Ponte 25 de Abril)", 38.6951, -9.1774, "기타"),
    ("크리스투 헤이 (Cristo Rei)", 38.6784, -9.1718, "기타"),
    ("MAAT (Museum of Art, Architecture & Technology)", 38.6953, -9.1942, "벨렝"),
    ("베라르두 박물관 (Museu Coleção Berardo)", 38.6978, -9.2071, "벨렝"),
    ("파스테이스 드 벨렝 (Pastéis de Belém)", 38.6970, -9.2035, "벨렝"),
    ("헤스타우라도레스 광장 (Praça dos Restauradores)", 38.7155, -9.1407, "신시가"),
    ("리베르다드 거리 (Avenida da Liberdade)", 38.7202, -9.1457, "신시가"),
    ("굴벤키앙 미술관 (Museu Calouste Gulbenkian)", 38.7379, -9.1541, "신시가"),
    ("호시우 광장 (Praça Dom Pedro IV)", 38.7139, -9.1399, "바이샤"),
    ("피게이라 광장 (Praça da Figueira)", 38.7132, -9.1374, "바이샤"),
    ("아우구스타 거리 (Rua Augusta)", 38.7104, -9.1367, "바이샤"),
    ("카르무 성당 (Convento do Carmo)", 38.7116, -9.1416, "바이후알투"),
    ("상 호케 성당 (Igreja de São Roque)", 38.7128, -9.1432, "바이후알투"),
    ("상 페드루 드 알칸타라 전망대 (Miradouro de São Pedro de Alcântara)", 38.7144, -9.1446, "바이후알투"),
    ("대성당 (Se)", 38.7102, -9.1323, "알파마"),
    ("산타 엘그라시아 성당 (Panteão Nacional)", 38.7176, -9.1245, "알파마")
]

# 지구별 색상 매핑
district_colors = {
    "바이샤": "blue",       # #00B0F0
    "벨렝": "red",          # #FF0000
    "바이후알투": "orange", # #FFC000
    "알파마": "green",      # #92D050
    "신시가": "pink",       # #FE01AE
    "서부": "red",        # #FF0000
    "기타": "gray"         # #797979
}

# 지도에 마커 추가
for place in places:
    place_name, lat, lon, district = place
    color = district_colors.get(district, "gray")  # 해당 지구 색상 적용, 없으면 기본 회색

    folium.Marker(
        location=[lat, lon],
        popup=place_name,  # 팝업: 한글 + 원어명
        icon=folium.Icon(color=color, icon="info-sign")  # 기본 핀 색상을 지구별 색상과 동일하게 설정
    ).add_to(lisbon_map)

# 지도 표시
lisbon_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# 지도 HTML 파일로 저장
lisbon_map.save("lisbon_map.html")

# Google Colab에서 다운로드할 수 있도록 파일 제공
from google.colab import files
files.download("lisbon_map.html")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4adb55bd5e44> in <cell line: 0>()
#       1 # 지도 HTML 파일로 저장
# ----> 2 lisbon_map.save("lisbon_map.html")
#       3
#       4 # Google Colab에서 다운로드할 수 있도록 파일 제공
#       5 from google.colab import files
#
# NameError: name 'lisbon_map' is not defined

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## 추가 리소스
#
# ### Colab에서 메모장 사용하기
#
# </div>
#
# - [Colaboratory 개요](/notebooks/basic_features_overview.ipynb)
# - [Markdown 가이드](/notebooks/markdown_guide.ipynb)
# - [라이브러리 가져오기 및 종속 항목 설치하기](/notebooks/snippets/importing_libraries.ipynb)
# - [GitHub에서 노트 저장 및 로드하기](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [대화형 양식](/notebooks/forms.ipynb)
# - [대화형 위젯](/notebooks/widgets.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="working-with-data"></a>
# ### 데이터로 작업하기
# </div>
#
# - [데이터 로드: 드라이브, 스프레드시트, Google Cloud Storage](/notebooks/io.ipynb)
# - [차트: 데이터 시각화하기](/notebooks/charts.ipynb)
# - [BigQuery 시작하기](/notebooks/bigquery.ipynb)
#
# <div class="markdown-google-sans">
#
# ### 머신러닝 단기집중과정
#
# <div>
#
# 다음은 Google 온라인 머신러닝 과정에서 가져온 일부 메모장입니다. <a href="https://developers.google.com/machine-learning/crash-course/">전체 과정 웹사이트</a>에서 자세한 내용을 확인하세요.
# - [Pandas DataFrame 소개](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [합성 데이터를 사용하는 tf.keras 선형 회귀](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="using-accelerated-hardware"></a>
# ### 가속 하드웨어 사용하기
# </div>
#
# - [GPU를 사용한 TensorFlow](/notebooks/gpu.ipynb)
# - [TPU를 사용한 TensorFlow](/notebooks/tpu.ipynb)

# %% [markdown]
# <div class="markdown-google-sans">
#
# <a name="machine-learning-examples"></a>
#
# ### 추천 예시
#
# </div>
#
# - <a href="https://colab.research.google.com/github/NVIDIA/NeMo/blob/stable/tutorials/VoiceSwapSample.ipynb">NeMo Voice Swap</a>: Nvidia의 NeMo 대화형 AI 툴킷을 사용하여 오디오 파일의 음성을 컴퓨터에서 생성된 음성으로 변환하세요.
#
# - <a href="https://tensorflow.org/hub/tutorials/tf2_image_retraining">이미지 분류기 재훈련</a>: 사전에 훈련된 이미지 분류기를 기반으로 꽃을 분류하기 위한 Keras 모델을 구축합니다.
# - <a href="https://tensorflow.org/hub/tutorials/tf2_text_classification">텍스트 분류</a>: IMDB 영화 리뷰를 <em>긍정적인 리뷰</em> 또는 <em>부정적인 리뷰</em>로 분류합니다.
# - <a href="https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization">스타일 트랜스퍼</a>: 딥 러닝을 사용하여 이미지 간에 스타일을 전이시킵니다.
# - <a href="https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa">Multilingual Universal Sentence Encoder Q&amp;A</a>: 머신러닝 모델을 사용하여 SQuAD 데이터 세트의 질문에 답변합니다.
# - <a href="https://tensorflow.org/hub/tutorials/tweening_conv3d">동영상 보간 유형</a>: 동영상에서 첫 프레임과 마지막 프레임 사이에 발생한 내용을 예측합니다.
